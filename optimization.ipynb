# %%
import random
import numpy as np
import pandas as pd
import open3d as o3d

from pathlib import Path
from itertools import product


random.seed(42)
o3d.utility.set_verbosity_level(o3d.utility.VerbosityLevel.Error)
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
import utils
import calibration_utils

import importlib
importlib.reload(utils)
importlib.reload(calibration_utils)
# Out:
# <module 'calibration_utils' from '/home/tom/Documents/UNT/csce6260/projects/kitti-experiments/calibration_utils.py'>

# %%
base = Path.home() / "kitti"
train_dir = base / "training"
velo_dir = train_dir / "velodyne"
point_cloud_train_files = sorted(velo_dir.glob("*.bin"))
calib_dir = train_dir / "calib"
calib_train_files = sorted(calib_dir.glob("*.txt"))
train_labels_dir = train_dir / "label_2"
kitti_train_labels = sorted(train_labels_dir.glob("*.txt"))

# %%
subset_size = 300
assert len(point_cloud_train_files) == len(calib_train_files) == len(kitti_train_labels)
random_indices = random.sample(range(len(point_cloud_train_files)), subset_size)
point_cloud_subset = [point_cloud_train_files[i] for i in random_indices]
calib_subset = [calib_train_files[i] for i in random_indices]
labels_subset = [kitti_train_labels[i] for i in random_indices]
print(f"Subset size: {len(point_cloud_subset)} point clouds, "
      f"{len(calib_subset)} calibs, {len(labels_subset)} labels")
# Out:
# Subset size: 300 point clouds, 300 calibs, 300 labels

# %%
def downsample(points, voxel_size=0.2):
    point_cloud = o3d.geometry.PointCloud()
    point_cloud.points = o3d.utility.Vector3dVector(points[:, :3])
    point_cloud = point_cloud.voxel_down_sample(voxel_size=voxel_size)
    return point_cloud

def segment(point_cloud):
    plane_model, inliers = point_cloud.segment_plane(distance_threshold=0.3, ransac_n=3, num_iterations=150)
    outlier_cloud = point_cloud.select_by_index(inliers, invert=True)
    return outlier_cloud

def cluster(outlier_cloud, eps=0.45, min_points=10):
    with o3d.utility.VerbosityContextManager(o3d.utility.VerbosityLevel.Debug) as cm:
        cluster_labels = np.array(outlier_cloud.cluster_dbscan(eps=eps, min_points=min_points, print_progress=False))
    return cluster_labels

# %%
MAX_POINTS = 300
MIN_POINTS = 25

def get_bbox_predictions(cluster_labels):
    predicted_bboxes = []
    clusters = pd.Series(range(len(cluster_labels))).groupby(cluster_labels, sort=False).apply(list).tolist()
    for cluster in clusters:
        nb_points = len(outlier_cloud.select_by_index(cluster).points)
        if (nb_points > MIN_POINTS and nb_points < MAX_POINTS):
            sub_cloud = outlier_cloud.select_by_index(cluster)
            pred_bbox = sub_cloud.get_axis_aligned_bounding_box()            
            predicted_bboxes.append(pred_bbox)
    return predicted_bboxes

# %%
def get_cam_to_velo_transform(calib):
    velo_to_cam = calib['Tr_velo_to_cam']
    velo_to_cam = np.vstack((velo_to_cam, [0, 0, 0, 1]))
    cam_to_velo = calibration_utils.inverse_rigid_transform(velo_to_cam)    
    return cam_to_velo

def get_ground_truth_bboxes(labels, cam_to_velo):
    gt_bboxes = []
    for label in labels:
        corners_3d_velo = calibration_utils.compute_box_3d(label, cam_to_velo)
        pcd = o3d.geometry.PointCloud()
        pcd.points = o3d.utility.Vector3dVector(corners_3d_velo)
        gt_bbox = pcd.get_axis_aligned_bounding_box()
        gt_bboxes.append(gt_bbox)
    return gt_bboxes

# %%
voxel_sizes = [0.05, 0.1, 0.15, 0.2]
dbscan_eps = [0.35, 0.4, 0.45, 0.5, 0.55]
min_points = [5, 10, 15, 20]

hyperparameter_grid = list(product(voxel_sizes, dbscan_eps, min_points))
print(f"\nTotal hyperparameter combinations: {len(hyperparameter_grid)}")
all_scores = []
for i, (v, eps, mp) in enumerate(hyperparameter_grid):
    total_TP, total_FP, total_FN = 0, 0, 0
    for cloud_file, calib_file, label_file in list(zip(point_cloud_subset, calib_subset, labels_subset)):
        points = utils.read_velodyne_bin(cloud_file)
        point_cloud = downsample(points, voxel_size=v)
        outlier_cloud = segment(point_cloud)
        cluster_labels = cluster(outlier_cloud, eps, mp)
        predicted_bboxes = get_bbox_predictions(cluster_labels)
        predicted_bboxes = list(filter(lambda b: b.min_bound[0] > 0, predicted_bboxes))
        labels = utils.parse_label_file(label_file)
        calib = utils.parse_calib_file(calib_file)
        cam_to_velo = get_cam_to_velo_transform(calib)
        gt_bboxes = get_ground_truth_bboxes(labels, cam_to_velo)
        results = utils.evaluate_metrics(gt_bboxes, predicted_bboxes, iou_threshold=0.2)
        total_TP += results['TP']
        total_FP += results['FP']
        total_FN += results['FN']
    precision = total_TP / (total_TP + total_FP) if (total_TP + total_FP) > 0 else 0
    recall = total_TP / (total_TP + total_FN) if (total_TP + total_FN) > 0 else 0
    f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0
    all_scores.append({
        "voxel_size": v,
        "eps": eps,
        "min_points": mp,
        "precision": precision,
        "recall": recall,
        "f1": f1_score,
        "raw_results": {'TP': total_TP, 'FP': total_FP, 'FN': total_FN}
    })
    break
# Out:
# Total hyperparameter combinations: 80
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 515
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 90
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 603
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 208
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 485
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 446
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 206
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 431
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 295
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 185
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 453
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 311
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 240
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 193
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 451
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 236
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 201
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 668
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 340
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 386
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 241
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 544
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 426
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 442
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 439
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 307
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 254
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 268
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 351
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 214
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 180
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 316
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 108
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 365
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 289
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 539
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 320
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 250
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 246
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 189
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 372
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 431
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 610
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 580
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 261
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 207
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 306
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 362
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 417
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 292
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 357
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 337
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 709
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 286
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 479
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 571
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 390
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 453
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 612
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 135
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 227
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 342
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 297
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 342
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 617
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 170
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 400
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 768
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 228
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 278
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 338
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 639
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 330
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 257
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 219
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 325
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 195
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 351
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 533
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 563
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 162
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 370
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 312
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 682
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 718
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 367
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 663
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 409
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 265
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 412
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 223
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 794
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 396
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 442
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 433
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 447
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 205
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 460
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 450
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 329
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 358
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 193
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 741
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 557
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 136
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 483
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 468
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 427
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 745
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 310
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 342
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 131
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 233
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 417
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 430
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 494
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 240
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 243
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 451
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 474
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 559
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 264
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 211
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 554
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 283
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 434
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 417
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 171
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 311
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 252
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 463
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 103
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 285
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 367
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 673
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 266
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 327
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 102
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 786
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 269
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 240
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 699
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 553
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 478
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 319
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 281
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 262
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 202
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 267
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 409
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 166
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 354
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 197
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 207
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 627
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 302
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 511
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 239
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 202
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 485
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 448
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 544
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 130
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 551
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 281
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 346
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 117
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 384
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 240
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 393
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 184
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 533
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 355
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 700
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 515
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 312
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 234
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 810
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 391
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 349
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 682
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 332
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 269
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 257
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 160
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 121
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 151
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 172
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 532
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 353
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 324
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 275
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 252
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 522
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 412
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 283
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 151
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 463
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 129
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 474
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 441
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 476
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 232
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 397
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 399
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 292
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 208
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 256
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 574
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 614
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 265
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 222
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 551
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 226
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 293
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 265
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 618
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 324
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 274
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 194
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 353
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 216
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 278
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 85
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 411
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 504
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 394
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 300
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 214
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 289
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 465
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 330
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 455
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 310
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 684
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 367
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 236
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 530
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 335
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 410
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 318
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 526
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 257
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 444
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 209
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 609
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 250
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 142
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 425
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 353
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 661
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 334
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 158
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 189
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 433
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 583
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 454
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 330
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 826
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 364
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 469
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 614
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 433
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 543
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 304
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 438
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 182
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 659
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 222
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 583
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 801
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 250
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 207
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 203
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 127
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 468
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 178
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 232
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 396
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 566
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 294
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 394
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 565
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 459
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 472
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 189
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 245
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 224
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 306
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 418
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 649
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 508
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 699
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 123
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 553
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 568
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 495
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 527
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 447
# [Open3D DEBUG] Precompute neighbors.
# [Open3D DEBUG] Done Precompute neighbors.
# [Open3D DEBUG] Compute Clusters
# [Open3D DEBUG] Done Compute Clusters: 209

# %%
all_scores_sorted = sorted(all_scores, key=lambda x: x["f1"], reverse=True)
top_n = 5
print(f"Top {top_n} configurations based on F1 score:")
for rank, entry in enumerate(all_scores_sorted[:top_n], 1):
    print(f"{rank}: voxel_size={entry['voxel_size']}, eps={entry['eps']}, min_points={entry['min_points']}")
    print(f"    Precision={entry['precision']:.3f}, Recall={entry['recall']:.3f}, F1={entry['f1']:.3f}")
    print(f"    Raw results: {entry['raw_results']}")
